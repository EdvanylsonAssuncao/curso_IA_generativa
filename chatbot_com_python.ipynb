# %% [markdown]
# <a href="https://colab.research.google.com/github/EdvanylsonAssuncao/curso_IA_generativa/blob/main/chatbot_com_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
import openai

# Configuração da chave do Open
CHAVE_API = userdata.get('OPENROUTER_API_KEY')

client = openai.OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=CHAVE_API
)

# Definir o modelo a ser utilizado
MODELO = "meta-llama/llama-4-maverick"

while True:
    pergunta = input("\nPergunta: ")
    if pergunta.lower() in ['sair', 'exit']:
        break

    resposta = client.chat.completions.create(
        model=MODELO,
        messages=[
            {"role": "user", "content": pergunta}
        ]
    )

    print(resposta.choices[0].message.content)
